# %%
import csv
import random
from datetime import datetime, timedelta
import pandas as pd
manual_sentences = [
    # FLIRTY (125 total)
    {"chat": "Good morning beautiful ☀️", "Flirt_Label": 1},
    {"chat": "You looked amazing today 😍", "Flirt_Label": 1},
    {"chat": "Can't stop thinking about you 🙈", "Flirt_Label": 1},
    {"chat": "Your smile is dangerous 🔥", "Flirt_Label": 1},
    {"chat": "You're too cute for your own good 😏", "Flirt_Label": 1},
    {"chat": "Lowkey have a crush on you", "Flirt_Label": 1},
    {"chat": "That outfit was fire yesterday 👀", "Flirt_Label": 1},
    {"chat": "Be honest, do you miss me?", "Flirt_Label": 1},
    {"chat": "You make my day better every time", "Flirt_Label": 1},
    {"chat": "If I could I'd hug you right now 🤗", "Flirt_Label": 1},
    {"chat": "Why are you so perfect? 😌", "Flirt_Label": 1},
    {"chat": "Come closer next time we meet 😉", "Flirt_Label": 1},
    {"chat": "Your voice is kinda addictive", "Flirt_Label": 1},
    {"chat": "I'd pick you over Netflix any day", "Flirt_Label": 1},
    {"chat": "Stop being so charming 😅", "Flirt_Label": 1},
    {"chat": "Tell me something I don't know about you", "Flirt_Label": 1},
    {"chat": "You're my favorite distraction ❤️", "Flirt_Label": 1},
    {"chat": "What if we went on a date?", "Flirt_Label": 1},
    {"chat": "You always know what to say", "Flirt_Label": 1},
    {"chat": "Imagine us together right now 🥰", "Flirt_Label": 1},
    {"chat": "Your laugh makes everything better", "Flirt_Label": 1},
    {"chat": "I kinda like you more than I should", "Flirt_Label": 1},
    {"chat": "That picture you sent... wow 😍", "Flirt_Label": 1},
    {"chat": "Do you believe in love at first text?", "Flirt_Label": 1},
    {"chat": "You're trouble and I like it", "Flirt_Label": 1},
    {"chat": "Keep talking, I love your voice", "Flirt_Label": 1},
    {"chat": "If looks could kill you'd be deadly 😉", "Flirt_Label": 1},
    {"chat": "You + me = perfect chemistry", "Flirt_Label": 1},
    {"chat": "Miss your face already 🥺", "Flirt_Label": 1},
    {"chat": "You're sweeter than my coffee ☕", "Flirt_Label": 1},
    {"chat": "Tonight feels empty without you", "Flirt_Label": 1},
    {"chat": "Your eyes tell better stories than words", "Flirt_Label": 1},
    {"chat": "Let's make bad decisions together 😈", "Flirt_Label": 1},
    {"chat": "You make boring days exciting", "Flirt_Label": 1},
    {"chat": "I'd fight the world for one smile from you", "Flirt_Label": 1},
    {"chat": "Call me when you're alone", "Flirt_Label": 1},
    {"chat": "You're my weakness, don't tell anyone", "Flirt_Label": 1},
    {"chat": "That was the hottest message ever 🔥", "Flirt_Label": 1},
    {"chat": "Do you come with a warning label?", "Flirt_Label": 1},
    {"chat": "I want all your attention tonight", "Flirt_Label": 1},
    {"chat": "Your texts give me butterflies 🦋", "Flirt_Label": 1},
    {"chat": "You're stuck in my head rent-free", "Flirt_Label": 1},
    {"chat": "One date and I'm calling you mine", "Flirt_Label": 1},
    {"chat": "Stop making me like you more 😩", "Flirt_Label": 1},
    {"chat": "I'd travel anywhere just to see you", "Flirt_Label": 1},
    {"chat": "Your vibe is everything I need", "Flirt_Label": 1},
    {"chat": "Let's skip work and run away together", "Flirt_Label": 1},
    {"chat": "You smell like home (in a good way)", "Flirt_Label": 1},
    {"chat": "I'm jealous of anyone who gets your time", "Flirt_Label": 1},
    {"chat": "Your good morning texts > coffee", "Flirt_Label": 1},
    {"chat": "Caught myself smiling at my phone again", "Flirt_Label": 1},
    {"chat": "You're the plot twist I didn't expect", "Flirt_Label": 1},
    {"chat": "I want to be your favorite hello", "Flirt_Label": 1},
    {"chat": "Your energy pulls me in every time", "Flirt_Label": 1},
    {"chat": "Let's make memories that last forever", "Flirt_Label": 1},
    {"chat": "You make my heart do that flip thing", "Flirt_Label": 1},
    {"chat": "Be mine, at least for tonight", "Flirt_Label": 1},
    {"chat": "I'd choose you in every lifetime", "Flirt_Label": 1},
    {"chat": "Your touch would solve all my problems", "Flirt_Label": 1},
    {"chat": "Save my number as 'future ex' 😏", "Flirt_Label": 1},
    {"chat": "You're my favorite kind of chaos", "Flirt_Label": 1},
    {"chat": "I want to get lost in your stories", "Flirt_Label": 1},
    {"chat": "Your silence speaks louder than words", "Flirt_Label": 1},
    {"chat": "Let's write our own love story", "Flirt_Label": 1},
    {"chat": "You fit perfectly in my daydreams", "Flirt_Label": 1},
    {"chat": "I'd wait forever for one moment with you", "Flirt_Label": 1},
    {"chat": "Your presence = instant happiness", "Flirt_Label": 1},
    {"chat": "Let's dance in the rain someday", "Flirt_Label": 1},
    {"chat": "You make time disappear", "Flirt_Label": 1},
    {"chat": "I want your goodnight and good morning", "Flirt_Label": 1},
    {"chat": "You're my safe place in chaos", "Flirt_Label": 1},
    {"chat": "Let's create moments worth remembering", "Flirt_Label": 1},
    {"chat": "Your laugh is my favorite sound", "Flirt_Label": 1},
    {"chat": "I'd choose messy hair with you over perfection", "Flirt_Label": 1},
    {"chat": "Keep shining, you're breathtaking", "Flirt_Label": 1},
    {"chat": "Let's make tonight unforgettable", "Flirt_Label": 1},
    {"chat": "You + I = trouble but the good kind", "Flirt_Label": 1},
    {"chat": "Your goodnight texts keep me up thinking", "Flirt_Label": 1},
    {"chat": "I save all your messages to reread later", "Flirt_Label": 1},
    {"chat": "You're my favorite notification", "Flirt_Label": 1},
    
    # NON-FLIrTY (125 total) 
    {"chat": "What are you doing tonight?", "Flirt_Label": 0},
    {"chat": "Did you finish the assignment?", "Flirt_Label": 0},
    {"chat": "Weather is nice today isn't it?", "Flirt_Label": 0},
    {"chat": "Meeting at 2pm sharp", "Flirt_Label": 0},
    {"chat": "Power is out at my place", "Flirt_Label": 0},
    {"chat": "Group call in 10 minutes", "Flirt_Label": 0},
    {"chat": "Traffic is terrible today", "Flirt_Label": 0},
    {"chat": "Check your email for the link", "Flirt_Label": 0},
    {"chat": "Battery dying, talk later", "Flirt_Label": 0},
    {"chat": "Exam results are out tomorrow", "Flirt_Label": 0},
    {"chat": "WiFi is down again", "Flirt_Label": 0},
    {"chat": "Don't forget the deadline", "Flirt_Label": 0},
    {"chat": "Store closing in 15 minutes", "Flirt_Label": 0},
    {"chat": "I'm cooking dinner tonight", "Flirt_Label": 0},
    {"chat": "Rent is due by Friday", "Flirt_Label": 0},
    {"chat": "Keys are on the table", "Flirt_Label": 0},
    {"chat": "Package delivered to your door", "Flirt_Label": 0},
    {"chat": "Server crashed, working on it", "Flirt_Label": 0},
    {"chat": "Meeting notes are in the drive", "Flirt_Label": 0},
    {"chat": "I'm running 10 minutes late", "Flirt_Label": 0},
    {"chat": "Water the plants before you leave", "Flirt_Label": 0},
    {"chat": "Conference call at 3pm", "Flirt_Label": 0},
    {"chat": "Grocery list is on fridge", "Flirt_Label": 0},
    {"chat": "Train delayed 20 minutes", "Flirt_Label": 0},
    {"chat": "Invoice sent to your email", "Flirt_Label": 0},
    {"chat": "I'm studying for finals", "Flirt_Label": 0},
    {"chat": "Light bulb burned out again", "Flirt_Label": 0},
    {"chat": "Project deadline extended", "Flirt_Label": 0},
    {"chat": "Car needs an oil change", "Flirt_Label": 0},
    {"chat": "Team meeting rescheduled", "Flirt_Label": 0},
    {"chat": "I'm at the coffee shop now", "Flirt_Label": 0},
    {"chat": "Rent payment confirmed", "Flirt_Label": 0},
    {"chat": "Phone charger is in drawer", "Flirt_Label": 0},
    {"chat": "Weather forecast says rain", "Flirt_Label": 0},
    {"chat": "Document saved in shared folder", "Flirt_Label": 0},
    {"chat": "Trash needs to go out", "Flirt_Label": 0},
    {"chat": "Power washing the driveway", "Flirt_Label": 0},
    {"chat": "Bank statement arrived today", "Flirt_Label": 0},
    {"chat": "Laundry day tomorrow", "Flirt_Label": 0},
    {"chat": "Gas prices went up again", "Flirt_Label": 0},
    {"chat": "Zoom link expired, new one coming", "Flirt_Label": 0},
    {"chat": "Dinner reservations confirmed", "Flirt_Label": 0},
    {"chat": "Password reset instructions sent", "Flirt_Label": 0},
    {"chat": "Microwave stopped working", "Flirt_Label": 0},
    {"chat": "Package tracking updated", "Flirt_Label": 0},
    {"chat": "Team lunch at 12:30pm", "Flirt_Label": 0},
    {"chat": "Fridge needs defrosting", "Flirt_Label": 0},
    {"chat": "Flight delayed 2 hours", "Flirt_Label": 0},
    {"chat": "Renters insurance renewal due", "Flirt_Label": 0},
    {"chat": "Printer ink running low", "Flirt_Label": 0},
    {"chat": "Bus schedule changed", "Flirt_Label": 0},
    {"chat": "Meeting minutes uploaded", "Flirt_Label": 0},
    {"chat": "I'm doing laundry right now", "Flirt_Label": 0},
    {"chat": "Car insurance payment due", "Flirt_Label": 0},
    {"chat": "Website maintenance tonight", "Flirt_Label": 0},
    {"chat": "Dry cleaning ready for pickup", "Flirt_Label": 0},
    {"chat": "Power bill arrived today", "Flirt_Label": 0},
    {"chat": "Group project meeting tomorrow", "Flirt_Label": 0},
    {"chat": "TV remote batteries dead", "Flirt_Label": 0},
    {"chat": "Delivery window 2-4pm", "Flirt_Label": 0},
    {"chat": "Grass needs mowing this weekend", "Flirt_Label": 0},
    {"chat": "Conference registration closed", "Flirt_Label": 0},
    {"chat": "AC filter needs changing", "Flirt_Label": 0},
    {"chat": "Bank hours end at 5pm", "Flirt_Label": 0},
    {"chat": "Team building event Friday", "Flirt_Label": 0},
    {"chat": "Dishwasher tablets running low", "Flirt_Label": 0},
    {"chat": "Final exam schedule posted", "Flirt_Label": 0},
    {"chat": "Mailbox key is with neighbor", "Flirt_Label": 0},
    {"chat": "Street cleaning tomorrow morning", "Flirt_Label": 0},
    {"chat": "Library books due Friday", "Flirt_Label": 0},
    {"chat": "Cell service spotty here", "Flirt_Label": 0},
    {"chat": "Parking permit expires soon", "Flirt_Label": 0},
    {"chat": "Water heater making noise", "Flirt_Label": 0},
    {"chat": "Tire pressure low warning", "Flirt_Label": 0},
    # WHATSAPP SYSTEM MESSAGES
    {"chat": "Missed voice call", "Flirt_Label": 0},
    {"chat": "Missed video call", "Flirt_Label": 0},
    {"chat": "<Media omitted>", "Flirt_Label": 0},
    {"chat": "This message was deleted", "Flirt_Label": 0},
    {"chat": "Missed voice call", "Flirt_Label": 0},
    {"chat": "Missed video call", "Flirt_Label": 0},
    {"chat": "<Media omitted>", "Flirt_Label": 0},
    {"chat": "This message was deleted", "Flirt_Label": 0},
    # ADDITIONAL NON-FLIrTY
    {"chat": "I'm heading to the gym now", "Flirt_Label": 0},
    {"chat": "How's work going today?", "Flirt_Label": 0},
    {"chat": "Need help with the project?", "Flirt_Label": 0},
    {"chat": "What's for lunch today?", "Flirt_Label": 0},
]

# Generate 1000 rows using manual sentences
dates = [datetime(2024, 1, 1) + timedelta(minutes=i*5) for i in range(1000)]
names = ["You", "Crush", "Ali", "Sara"]

rows = []
for i, dt in enumerate(dates):
    # Pick random manual sentence (preserves Flirt_Label)
    manual_msg = random.choice(manual_sentences)
    sender = random.choice(names)
    
    rows.append({
        "date": dt.strftime("%d/%m/%Y"),
        "time": dt.strftime("%I:%M %p").lower(),
        "name": sender,
        "chat": manual_msg["chat"],
        "Flirt_Label": manual_msg["Flirt_Label"]
    })

# Write to CSV
with open("whatsapp_flirt_dataset_manual.csv", "w", newline="", encoding="utf-8") as f:
    writer = csv.DictWriter(f, fieldnames=["date", "time", "name", "chat", "Flirt_Label"])
    writer.writeheader()
    writer.writerows(rows)

print("File created: whatsapp_flirt_dataset_manual.csv")
# Out:
# File created: whatsapp_flirt_dataset_manual.csv
